# %% [markdown]
# # Ex7 - Model Regularization in Practice, an example with Keras and TensorFlow 2.0
#
# In this task, you are going to see the differences between applying regularization vs. not applying, in terms of model training on some dataset.
# The dataset we will use is Iris flowers, a classic SKLearn dataset.
#
# Inspired by [BindiChen](https://github.com/BindiChen)

# %%
# Relevant imports
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()
# Out:
# 2022-03-20 10:10:35.541139: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-20 10:10:35.541193: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Exploring data

# %%
# Load data into a DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Convert datatype to float
df = df.astype(float)
# append "target" and name it "label"
df['label'] = iris.target
# Use string label instead
df['label'] = df.label.replace(dict(enumerate(iris.target_names)))

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#     label
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ### Preparing data for Keras and TensorFlow

# %%
# label -> one-hot encoding, doing so because we are in a classification problem
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)
# drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label_setosa  label_versicolor  label_virginica
# 0             1                 0                0
# 1             1                 0                0
# 2             1                 0                0
# 3             1                 0                0
# 4             1                 0                0

# %%
# Creating X and y

X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
# Convert DataFrame into np array
X = np.asarray(X)

y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
# Convert DataFrame into np array
y = np.asarray(y)

# %%
# TODO: Split the data set in a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120, 3)
# (30, 3)

# %% [markdown]
# ## 1. Build an unregularized neural network model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# TODO: Build the architecture below:
# Sequential of:
# Dense of 64 neurons, with input shape (4,), activation = relu
# Dense of 128 neurons,activation = relu
# Dense of 128 neurons,activation = relu
# Dense of 128 neurons,activation = relu
# Dense of 64 neurons, activation = relu
# Dense of 64 neurons, activation = relu
# Dense of 64 neurons, activation = relu
# Dense of 3 neurons, activation = softmax for the classification task
# TODO: make sure to return the model from that function

def create_model():
    model = Sequential([Dense(64, activation='relu', input_shape=(4,)),
                       Dense(128, activation='relu'),
                       Dense(128, activation='relu'),
                       Dense(128, activation='relu'),
                       Dense(64, activation='relu'),
                       Dense(64, activation='relu'),
                       Dense(64, activation='relu'),
                       Dense(3, activation='softmax')])
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 58,435
# Trainable params: 58,435
# Non-trainable params: 0
# _________________________________________________________________
# 2022-03-20 10:10:39.322754: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-20 10:10:39.322799: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-20 10:10:39.322830: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (driver): /proc/driver/nvidia/version does not exist
# 2022-03-20 10:10:39.323197: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Compile the model

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=('accuracy')
    ### TODO: Compile with adam optimizer, categorical cross entropy loss, 'accuracy' as metric
)

# %% [markdown]
# ### Fit the model to the training data

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 1s - loss: 1.0948 - accuracy: 0.5000 - val_loss: 1.0057 - val_accuracy: 0.7000 - 1s/epoch - 459ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 0.9919 - accuracy: 0.6778 - val_loss: 0.9341 - val_accuracy: 0.6667 - 58ms/epoch - 19ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.9380 - accuracy: 0.6556 - val_loss: 0.8013 - val_accuracy: 0.6667 - 49ms/epoch - 16ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.7980 - accuracy: 0.6556 - val_loss: 0.6747 - val_accuracy: 0.6667 - 45ms/epoch - 15ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.5733 - val_accuracy: 0.8667 - 48ms/epoch - 16ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.5958 - accuracy: 0.7556 - val_loss: 0.5012 - val_accuracy: 0.6667 - 45ms/epoch - 15ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0
- val_accuracy: 0.9667 - 36ms/epoch - 12ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.0757 - accuracy: 0.9778 - val_loss: 0.0918 - val_accuracy: 0.9333 - 29ms/epoch - 10ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.0756 - accuracy: 0.9556 - val_loss: 0.0840 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.0751 - accuracy: 0.9667 - val_loss: 0.1535 - val_accuracy: 0.9333 - 33ms/epoch - 11ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.1402 - accuracy: 0.9333 - val_loss: 0.1166 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.0803 - accuracy: 0.9667 - val_loss: 0.1036 - val_accuracy: 0.9333 - 34ms/epoch - 11ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.0974 - accuracy: 0.9556 - val_loss: 0.0832 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0722 - accuracy: 0.9778 - val_loss: 0.1005 - val_accuracy: 0.9667 - 35ms/epoch - 12ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.0871 - accuracy: 0.9667 - val_loss: 0.0993 - val_accuracy: 0.9667 - 50ms/epoch - 17ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0765 - accuracy: 0.9667 - val_loss: 0.1171 - val_accuracy: 0.9000 - 31ms/epoch - 10ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0795 - accuracy: 0.9556 - val_loss: 0.0976 - val_accuracy: 0.9333 - 33ms/epoch - 11ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.0698 - accuracy: 0.9778 - val_loss: 0.0877 - val_accuracy: 0.9667 - 37ms/epoch - 12ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0823 - accuracy: 0.9667 - val_loss: 0.0823 - val_accuracy: 0.9667 - 34ms/epoch - 11ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.0634 - accuracy: 0.9778 - val_loss: 0.1929 - val_accuracy: 0.9333 - 34ms/epoch - 11ms/step

# %% [markdown]
# ### Model Evaluation

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
plot_metric(history, 'accuracy')


### TODO: Q: what is the name of this phenomena?

# %%
plot_metric(history, 'loss')

# %% [markdown]
# Plot the training and validation loss
#
# Finally, let's plot the loss vs. epochs graph on the training and validation sets
#
# From the graph, we can see that the model has vastly overfit the training data, so it outperform the validation set

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.0846 - accuracy: 0.9667 - 21ms/epoch - 21ms/step
# [0.08462801575660706, 0.9666666388511658]

# %% [markdown]
# ## 2. Adding L2 regularization and Dropout

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2

### TODO:
### You should build the same model as above, but this time:
# 1. Dropout layer, with rate should follow each Dense layer, except the last one (Dense of 3)
# 2.factor should be the input of l2 regularization in each Dense layer
# 3. Don't forget to return the model
# kernel_regularizer=regularizers.l2(0.01)
def create_regularized_model(factor, rate):
    model = Sequential([Dense(64, activation='relu', input_shape=(4,), kernel_regularizer=l2(factor)),
                       Dropout(rate),
                       Dense(128, activation='relu', kernel_regularizer=l2(factor)),
                       Dropout(rate),
                       Dense(128, activation='relu', kernel_regularizer=l2(factor)),
                       Dropout(rate),
                       Dense(128, activation='relu', kernel_regularizer=l2(factor)),
                       Dropout(rate),
                       Dense(64, activation='relu', kernel_regularizer=l2(factor)),
                       Dropout(rate),
                       Dense(64, activation='relu', kernel_regularizer=l2(factor)),
                       Dropout(rate),
                       Dense(64, activation='relu', kernel_regularizer=l2(factor)),
                       Dropout(rate),
                       Dense(3, activation='softmax', kernel_regularizer=l2(factor))])
    return model

# %%
# Re-build the model with weight decay and dropout layers
model = create_regularized_model(1e-5, 0.3)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                320
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_15 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 58,435
# Trainable params: 58,435
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=('accuracy')
    ### TODO: Compile with adam optimizer, categorical cross entropy loss, 'accuracy' as metric
)

# %%
# Train the model, with some of the data reserved for validation
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 1s - loss: 1.1839 - accuracy: 0.3556 - val_loss: 1.1220 - val_accuracy: 0.3000 - 1s/epoch - 364ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 1.1647 - accuracy: 0.3556 - val_loss: 1.1158 - val_accuracy: 0.2000 - 32ms/epoch - 11ms/step
# Epoch 3/200
# 3/3 - 0s - loss:
ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.1412 - accuracy: 0.9556 - val_loss: 0.0769 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.1453 - accuracy: 0.9444 - val_loss: 0.0804 - val_accuracy: 0.9667 - 34ms/epoch - 11ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.1965 - accuracy: 0.9556 - val_loss: 0.0646 - val_accuracy: 1.0000 - 34ms/epoch - 11ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.0964 - accuracy: 0.9667 - val_loss: 0.0702 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.1788 - accuracy: 0.9556 - val_loss: 0.0726 - val_accuracy: 0.9667 - 37ms/epoch - 12ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.2200 - accuracy: 0.9444 - val_loss: 0.0765 - val_accuracy: 0.9667 - 37ms/epoch - 12ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.1294 - accuracy: 0.9444 - val_loss: 0.0611 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.1565 - accuracy: 0.9667 - val_loss: 0.0589 - val_accuracy: 1.0000 - 34ms/epoch - 11ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.1106 - accuracy: 0.9556 - val_loss: 0.0606 - val_accuracy: 1.0000 - 33ms/epoch - 11ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.1779 - accuracy: 0.9556 - val_loss: 0.0640 - val_accuracy: 1.0000 - 36ms/epoch - 12ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.1094 - accuracy: 0.9667 - val_loss: 0.0706 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.1394 - accuracy: 0.9222 - val_loss: 0.0782 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.0843 - accuracy: 0.9667 - val_loss: 0.0741 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.1379 - accuracy: 0.9556 - val_loss: 0.0925 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.1309 - accuracy: 0.9556 - val_loss: 0.1261 - val_accuracy: 0.9333 - 34ms/epoch - 11ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.1681 - accuracy: 0.9556 - val_loss: 0.1047 - val_accuracy: 0.9333 - 33ms/epoch - 11ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.1157 - accuracy: 0.9667 - val_loss: 0.0834 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.1185 - accuracy: 0.9778 - val_loss: 0.0765 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.1372 - accuracy: 0.9556 - val_loss: 0.0700 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.1448 - accuracy: 0.9667 - val_loss: 0.0675 - val_accuracy: 0.9667 - 34ms/epoch - 11ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.1759 - accuracy: 0.9556 - val_loss: 0.0929 - val_accuracy: 0.9333 - 35ms/epoch - 12ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.0880 - accuracy: 0.9667 - val_loss: 0.0840 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.2178 - accuracy: 0.9333 - val_loss: 0.0684 - val_accuracy: 0.9667 - 35ms/epoch - 12ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.1792 - accuracy: 0.9556 - val_loss: 0.1411 - val_accuracy: 0.9333 - 34ms/epoch - 11ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.1992 - accuracy: 0.8778 - val_loss: 0.1333 - val_accuracy: 0.9333 - 35ms/epoch - 12ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.2039 - accuracy: 0.9111 - val_loss: 0.1014 - val_accuracy: 0.9667 - 37ms/epoch - 12ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.1744 - accuracy: 0.9333 - val_loss: 0.1154 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.1573 - accuracy: 0.9444 - val_loss: 0.1223 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.1798 - accuracy: 0.8889 - val_loss: 0.1135 - val_accuracy: 0.9667 - 37ms/epoch - 12ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.1734 - accuracy: 0.9333 - val_loss: 0.0961 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.1455 - accuracy: 0.9556 - val_loss: 0.0860 - val_accuracy: 1.0000 - 34ms/epoch - 11ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.1337 - accuracy: 0.9556 - val_loss: 0.0808 - val_accuracy: 1.0000 - 32ms/epoch - 11ms/step

# %% [markdown]
# ### Plot the learning curves

# %%
plot_metric(history, 'loss')

# %%
plot_metric(history, 'accuracy')

# %% [markdown]
# Here, you can see that the overfitting is not completely fixed, but there is a signficant improvement when we compare it to the unregularized model

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.0704 - accuracy: 1.0000 - 19ms/epoch - 19ms/step
# [0.07036321610212326, 1.0]

# %% [markdown]
# ## That's it
#
# Now you can see how regularization can be used and will help within the mentioned phenomena, which we discussed in class.
